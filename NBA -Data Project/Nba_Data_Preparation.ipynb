# %% [markdown]
# # Nba - Data Preparation

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading data

# %%
basketball_stats = pd.read_csv('Data_csvs\players_stats_by_season_full_details.csv') 
nba_records = pd.read_csv('Data_csvs\Team_Records.csv')

# %%
basketball_stats.head()
# Out:
#   League       Season           Stage                 Player Team  GP     MIN  \
# 0    NBA  2019 - 2020  Regular_Season           James Harden  HOU  68  2482.6
# 1    NBA  2019 - 2020  Regular_Season         Damian Lillard  POR  66  2473.7
# 2    NBA  2019 - 2020  Regular_Season           Devin Booker  PHX  70  2511.8
# 3    NBA  2019 - 2020  Regular_Season  Giannis Antetokounmpo  MIL  63  1916.9
# 4    NBA  2019 - 2020  Regular_Season             Trae Young  ATL  60  2120.1
#
#    FGM   FGA  3PM  ...   PTS  birth_year  birth_month    birth_date  height  \
# 0  672  1514  299  ...  2335      1989.0          Aug  Aug 26, 1989  06-May
# 1  624  1349  270  ...  1978      1990.0          Jul  Jul 15, 1990  06-Mar
# 2  627  1283  141  ...  1863      1996.0          Oct  Oct 30, 1996  06-Jun
# 3  685  1238   89  ...  1857      1994.0          Dec   Dec 6, 1994  06-Nov
# 4  546  1249  205  ...  1778      1998.0          Sep  Sep 19, 1998  06-Feb
#
# ...

# %%
basketball_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53798 entries, 0 to 53797
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   League       53798 non-null  object
#  1   Season       53798 non-null  object
#  2   Stage        53798 non-null  object
#  3   Player       53798 non-null  object
#  4   Team         53787 non-null  object
#  5   GP           53798 non-null  int64
#  6   MIN          53798 non-null  float64
#  7   FGM          53798 non-null  int64
#  8   FGA          53798 non-null  int64
#  9   3PM          53798 non-null  int64
#  10  3PA          53798 non-null  int64
#  11  FTM          53798 non-null  int64
#  12  FTA          53798 non-null  int64
#  13  TOV          53798 non-null  int64
#  14  PF           53798 non-null  int64
#  15  ORB          53798 non-null  int64
#  16  DRB          53798 non-null  int64
#  17  REB          53798 non-null  int64
# ...

# %%
basketball_stats.isna().sum()
# Out:
# League             0
# Season             0
# Stage              0
# Player             0
# Team              11
# GP                 0
# MIN                0
# FGM                0
# FGA                0
# 3PM                0
# 3PA                0
# FTM                0
# FTA                0
# TOV                0
# PF                 0
# ORB                0
# DRB                0
# REB                0
# AST                0
# STL                0
# BLK                0
# PTS                0
# birth_year       319
# birth_month      319
# birth_date       319
# height            74
# height_cm         74
# weight          4566
# weight_kg       4566
# nationality        7
# high_school    30247
# dtype: int64

# %%
basketball_stats.describe
# Out:
# <bound method NDFrame.describe of       League       Season           Stage                 Player Team  GP  \
# 0        NBA  2019 - 2020  Regular_Season           James Harden  HOU  68
# 1        NBA  2019 - 2020  Regular_Season         Damian Lillard  POR  66
# 2        NBA  2019 - 2020  Regular_Season           Devin Booker  PHX  70
# 3        NBA  2019 - 2020  Regular_Season  Giannis Antetokounmpo  MIL  63
# 4        NBA  2019 - 2020  Regular_Season             Trae Young  ATL  60
# ...      ...          ...             ...                    ...  ...  ..
# 53793    NBA  1999 - 2000        Playoffs            John Salley  LAL  18
# 53794    NBA  1999 - 2000        Playoffs          Muggsy Bogues  TOR   3
# 53795    NBA  1999 - 2000        Playoffs        Jerome Williams  DET   3
# 53796    NBA  1999 - 2000        Playoffs       Randy Livingston  PHX   7
# 53797    NBA  1999 - 2000        Playoffs          Doug Christie  TOR   3
#
# ...

# %%
basketball_stats.League.value_counts().plot(kind='bar', figsize= (18, 8), )
plt.title('Leagues data count')
plt.ylabel('Count')
plt.xlabel('Leagues')
plt.show()

# %% [markdown]
# ### Cleaning the data for analysis

# %%
nba = basketball_stats.loc[basketball_stats.League.isin(['NBA'])].reset_index()
nba
# Out:
#       index League       Season           Stage                 Player Team  \
# 0         0    NBA  2019 - 2020  Regular_Season           James Harden  HOU
# 1         1    NBA  2019 - 2020  Regular_Season         Damian Lillard  POR
# 2         2    NBA  2019 - 2020  Regular_Season           Devin Booker  PHX
# 3         3    NBA  2019 - 2020  Regular_Season  Giannis Antetokounmpo  MIL
# 4         4    NBA  2019 - 2020  Regular_Season             Trae Young  ATL
# ...     ...    ...          ...             ...                    ...  ...
# 7485  53793    NBA  1999 - 2000        Playoffs            John Salley  LAL
# 7486  53794    NBA  1999 - 2000        Playoffs          Muggsy Bogues  TOR
# 7487  53795    NBA  1999 - 2000        Playoffs        Jerome Williams  DET
# 7488  53796    NBA  1999 - 2000        Playoffs       Randy Livingston  PHX
# 7489  53797    NBA  1999 - 2000        Playoffs          Doug Christie  TOR
#
# ...

# %% [markdown]
# ### Droping doubled columns, not needed columns.

# %%
list(nba.columns)
# Out:
# ['index',
#  'League',
#  'Season',
#  'Stage',
#  'Player',
#  'Team',
#  'GP',
#  'MIN',
#  'FGM',
#  'FGA',
#  '3PM',
#  '3PA',
#  'FTM',
#  'FTA',
#  'TOV',
#  'PF',
#  'ORB',
#  'DRB',
#  'REB',
#  'AST',
#  'STL',
#  'BLK',
#  'PTS',
#  'birth_year',
#  'birth_month',
#  'birth_date',
#  'height',
#  'height_cm',
#  'weight',
#  'weight_kg',
#  'nationality',
#  'high_school']

# %%
nba.drop(['League', 'height', 'weight', 'high_school', 'birth_year', 'birth_month', 'index'], axis=1, inplace=True)
nba.columns.to_list()
# Out:
# ['Season',
#  'Stage',
#  'Player',
#  'Team',
#  'GP',
#  'MIN',
#  'FGM',
#  'FGA',
#  '3PM',
#  '3PA',
#  'FTM',
#  'FTA',
#  'TOV',
#  'PF',
#  'ORB',
#  'DRB',
#  'REB',
#  'AST',
#  'STL',
#  'BLK',
#  'PTS',
#  'birth_date',
#  'height_cm',
#  'weight_kg',
#  'nationality']

# %%
nba.describe()
# Out:
#                 GP          MIN          FGM          FGA          3PM  \
# count  7490.000000  7490.000000  7490.000000  7490.000000  7490.000000
# mean     49.384913  1314.630013   208.727103   456.567957    40.623498
# std      31.474893   964.844408   184.488201   397.372907    52.363572
# min       1.000000     0.700000     0.000000     0.000000     0.000000
# 25%      12.000000   277.200000    39.000000    88.000000     1.000000
# 50%      66.000000  1344.250000   173.000000   379.000000    14.000000
# 75%      77.000000  2133.325000   322.000000   712.000000    69.000000
# max      85.000000  3485.000000   978.000000  2173.000000   402.000000
#
#                3PA          FTM          FTA          TOV           PF  \
# count  7490.000000  7490.000000  7490.000000  7490.000000  7490.000000
# mean    112.549666   103.739386   135.812817    75.205474   110.802270
# std     138.022068   112.961595   143.414609    67.581017    79.721384
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7490 entries, 0 to 7489
# Data columns (total 25 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Season       7490 non-null   object
#  1   Stage        7490 non-null   object
#  2   Player       7490 non-null   object
#  3   Team         7490 non-null   object
#  4   GP           7490 non-null   int64
#  5   MIN          7490 non-null   float64
#  6   FGM          7490 non-null   int64
#  7   FGA          7490 non-null   int64
#  8   3PM          7490 non-null   int64
#  9   3PA          7490 non-null   int64
#  10  FTM          7490 non-null   int64
#  11  FTA          7490 non-null   int64
#  12  TOV          7490 non-null   int64
#  13  PF           7490 non-null   int64
#  14  ORB          7490 non-null   int64
#  15  DRB          7490 non-null   int64
#  16  REB          7490 non-null   int64
#  17  AST          7490 non-null   int64
# ...

# %% [markdown]
# ### Conclusions:
# - No Nan values in data, all columns are with data.
# - There are no players that didnt play any game in the data.
# - Data is ready to start analysis.

# %% [markdown]
# # Optional interesting queries

# %%
nba.height_cm.value_counts().plot(kind='bar')
plt.title('Players Height')
plt.xlabel('Height')
plt.ylabel("Num of players")
# Out:
# Text(0, 0.5, 'Num of players')

# %%
nba.height_cm.value_counts(normalize=True)
# Out:
# 206.0    0.124299
# 201.0    0.114019
# 203.0    0.100000
# 208.0    0.091989
# 211.0    0.089720
# 198.0    0.080107
# 191.0    0.079840
# 196.0    0.061682
# 193.0    0.058745
# 213.0    0.055140
# 185.0    0.043124
# 188.0    0.036716
# 183.0    0.024433
# 216.0    0.017223
# 180.0    0.006275
# 218.0    0.005073
# 221.0    0.003738
# 178.0    0.002537
# 175.0    0.002270
# 229.0    0.001869
# 165.0    0.000668
# 160.0    0.000267
# 224.0    0.000267
# Name: height_cm, dtype: float64

# %% [markdown]
# ### Conclusion:
# - Sum the NBA player by height.
# - Most frequent heights are (in centimeter): 206, 201, 203, 208, 211. (more than 50% of the players)
# - Less frequent heights are (in centimeter): 224, 160, 165, 229, 175.

# %%
nba.Season.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Conclusions:
# - Almost same amount of data from each season.
# - Most players data are from 2016-2019. Three first bars.

# %%
nba.Stage.value_counts().plot(kind='pie', autopct='%.2f', legend=True)
plt.title("Season VS Playoffs")
plt.show()

# %% [markdown]
# ### Conclusions:
# - More regular season games then playoffs.
#
# Possible Quiery:
# - "According to the player stats can we precidt if he playes in the playoff or in the regular season".

# %%
nba.nationality.value_counts()
# Out:
# United States              5965
# France                      129
# Canada                       90
# Spain                        79
# Argentina                    63
#                            ...
# Saint Lucia / Canada          1
# United States / Croatia       1
# United States / Israel        1
# Tanzania                      1
# Angola                        1
# Name: nationality, Length: 94, dtype: int64

# %% [markdown]
# ### Conclusions:
# - As expected most nba players comes from the United States.
# - We have repeats and combined nationality.
#
# Possible Queiries:
# 1. Statitics values by nationality.
# 2. Does a player that is international average better stats.
# 3. Highest statistics by countries.
# 4. Does the same stats for international player or local player gives the same amount of minutes per game.

# %%
nba.Player.loc[nba.Stage == 'Playoffs'].value_counts().head()
# Out:
# Tony Parker      17
# Tim Duncan       16
# Manu Ginobili    15
# Dirk Nowitzki    15
# Jason Kidd       14
# Name: Player, dtype: int64

# %%
nba.Team.value_counts().plot(kind='bar', figsize=(14,7))
plt.xticks(rotation=0)
plt.title("Players By Teams")
plt.xlabel('Teams')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Conclusion:
# - We can see that SAS is the team with the most change in their roster in the last 20 years.
# - Van as changed their roster the less amount of times. (The team changed to Mem after 2000-01 season)
# - Sea as changed their roster the second less amount of times. (The team changed to OKC after 2008-09 season)

# %%
nba.columns
# Out:
# Index(['Season', 'Stage', 'Player', 'Team', 'GP', 'MIN', 'FGM', 'FGA', '3PM',
#        '3PA', 'FTM', 'FTA', 'TOV', 'PF', 'ORB', 'DRB', 'REB', 'AST', 'STL',
#        'BLK', 'PTS', 'birth_date', 'height_cm', 'weight_kg', 'nationality'],
#       dtype='object')

# %% [markdown]
# ### Calculating new columns that may help for later analysis

# %%
nba['PPG'] = (nba.PTS/nba.GP).round(2)
nba['APG'] = (nba.AST/nba.GP).round(2)
nba['RPG'] = (nba.REB/nba.GP).round(2)
nba['ORPG'] = (nba.ORB/nba.GP).round(2)
nba['DRPG'] = (nba.DRB/nba.GP).round(2)
nba['SPG'] = (nba.STL/nba.GP).round(2)
nba['BPG'] = (nba.BLK/nba.GP).round(2)
nba['FPG'] = (nba.PF/nba.GP).round(2)
nba['MPG'] = (nba.MIN/nba.GP).round(2)
nba['TPG'] = (nba.TOV/nba.GP).round(2)
nba['FT%'] = nba.apply(lambda x: (x['FTM'] / x['FTA']) if x['FTA'] > 15 else np.nan, axis=1)
nba['FG%'] = nba.apply(lambda x: (x['FGM'] / x['FGA']) if x['FGA'] > 15 else np.nan, axis=1)
nba['3P%'] = nba.apply(lambda x: (x['3PM'] / x['3PA']) if x['3PA'] > 15 else np.nan, axis=1)
    
nba.head()
# Out:
#         Season           Stage                 Player Team  GP     MIN  FGM  \
# 0  2019 - 2020  Regular_Season           James Harden  HOU  68  2482.6  672
# 1  2019 - 2020  Regular_Season         Damian Lillard  POR  66  2473.7  624
# 2  2019 - 2020  Regular_Season           Devin Booker  PHX  70  2511.8  627
# 3  2019 - 2020  Regular_Season  Giannis Antetokounmpo  MIL  63  1916.9  685
# 4  2019 - 2020  Regular_Season             Trae Young  ATL  60  2120.1  546
#
#     FGA  3PM  3PA  ...  ORPG   DRPG   SPG   BPG   FPG    MPG   TPG       FT%  \
# 0  1514  299  843  ...  1.03   5.53  1.84  0.88  3.34  36.51  4.53  0.865000
# 1  1349  270  674  ...  0.50   3.80  1.06  0.33  1.73  37.48  2.94  0.888031
# 2  1283  141  398  ...  0.41   3.83  0.70  0.26  3.04  35.88  3.77  0.919450
# 3  1238   89  293  ...  2.22  11.37  0.97  1.05  3.10  30.43  3.65  0.632750
# 4  1249  205  568  ...  0.53   3.72  1.08  0.13  1.73  35.34  4.82  0.860465
#
#         FG%       3P%
# 0  0.443857  0.354686
# ...

# %%
print("Top 5 players last 20 years 3P% (atleast 15 shots)")
nba.nlargest(5, '3P%')
# Out:
# Top 5 players last 20 years 3P% (atleast 15 shots)
#            Season           Stage           Player Team  GP     MIN  FGM  FGA  \
# 4722  2007 - 2008        Playoffs        Raja Bell  PHX   5   214.8   21   37
# 4248  2008 - 2009  Regular_Season    Dahntay Jones  DEN  79  1425.7  154  336
# 2220  2014 - 2015        Playoffs    Alan Anderson  BRK   6   141.8   25   41
# 6399  2002 - 2003        Playoffs     Derek Fisher  LAL  12   424.0   53  102
# 1018  2017 - 2018        Playoffs  Khris Middleton  MIL   7   275.4   67  112
#
#       3PM  3PA  ...  ORPG  DRPG   SPG   BPG   FPG    MPG   TPG       FT%  \
# 4722   13   20  ...  1.20  4.40  0.40  0.20  3.80  42.96  1.00  0.812500
# 4248   11   17  ...  0.73  1.39  0.62  0.24  2.52  18.05  0.86  0.728477
# 2220   10   16  ...  0.33  3.17  0.67  0.17  1.50  23.63  1.33       NaN
# 6399   29   47  ...  0.42  2.58  1.50  0.08  3.25  35.33  1.50  0.818182
# 1018   25   41  ...  0.14  5.00  0.86  0.71  4.29  39.34  2.29  0.736842
#
# ...

# %%
print("Top 5 players last 20 years FG% (atleast 15 shots)")
nba.nlargest(5, 'FG%')
# Out:
# Top 5 players last 20 years FG% (atleast 15 shots)
#            Season           Stage             Player Team  GP     MIN  FGM  \
# 2623  2013 - 2014        Playoffs     Brandan Wright  DAL   6    90.4   15
# 2910  2012 - 2013        Playoffs     Chris Andersen  MIA  20   303.4   46
# 155   2019 - 2020  Regular_Season  Mitchell Robinson  NYK  61  1412.5  253
# 1492  2016 - 2017        Playoffs       JaVale McGee  GSW  16   148.5   41
# 3339  2011 - 2012        Playoffs        Joakim Noah  CHI   3    99.1   19
#
#       FGA  3PM  3PA  ...  ORPG  DRPG   SPG   BPG   FPG    MPG   TPG       FT%  \
# 2623   18    0    0  ...  0.83  1.17  0.33  1.00  1.33  15.07  0.33       NaN
# 2910   57    0    0  ...  1.60  2.20  0.45  1.10  2.65  15.17  0.55  0.734694
# 155   341    0    0  ...  3.05  3.97  0.85  1.95  3.18  23.16  0.61  0.567568
# 1492   56    0    0  ...  1.38  1.62  0.12  0.94  1.94   9.28  0.50  0.722222
# ...

# %%
print("Top 5 players last 20 years FT% (atleast 15 shots)")
nba.nlargest(5, 'FT%')
# Out:
# Top 5 players last 20 years FT% (atleast 15 shots)
#            Season           Stage          Player Team  GP     MIN  FGM  FGA  \
# 187   2019 - 2020  Regular_Season      Tony Snell  DET  59  1641.1  170  382
# 635   2018 - 2019        Playoffs  Gordon Hayward  BOS   9   266.6   29   70
# 2901  2012 - 2013        Playoffs       Gary Neal  SAS  21   390.3   52  135
# 3360  2011 - 2012        Playoffs  Gordon Hayward  UTA   4   122.5    6   33
# 5393  2005 - 2006        Playoffs    Kevin Martin  SAC   6   196.8   22   54
#
#       3PM  3PA  ...  ORPG  DRPG   SPG   BPG   FPG    MPG   TPG  FT%       FG%  \
# 187   102  254  ...  0.15  1.73  0.54  0.25  1.71  27.82  0.53  1.0  0.445026
# 635     9   24  ...  0.33  3.67  0.67  0.33  1.78  29.62  1.67  1.0  0.414286
# 2901   23   66  ...  0.05  2.10  0.14  0.05  1.57  18.59  0.62  1.0  0.385185
# 3360    1   12  ...  0.50  2.25  0.75  0.00  1.00  30.62  0.75  1.0  0.181818
# ...

# %%
nba.sort_values(['Team', 'Season', 'Stage'], inplace=True, ascending=False)
nba.reset_index().drop(['index'], axis=1)
# Out:
#            Season           Stage           Player Team  GP     MIN  FGM  \
# 0     2019 - 2020  Regular_Season     Bradley Beal  WAS  57  2053.2  593
# 1     2019 - 2020  Regular_Season    Davis Bertans  WAS  54  1583.0  265
# 2     2019 - 2020  Regular_Season        Ish Smith  WAS  68  1787.0  308
# 3     2019 - 2020  Regular_Season  Troy Brown, Jr.  WAS  69  1781.9  273
# 4     2019 - 2020  Regular_Season   Shabazz Napier  WAS  56  1344.5  188
# ...           ...             ...              ...  ...  ..     ...  ...
# 7485  1999 - 2000  Regular_Season   Alan Henderson  ATL  82  2775.0  429
# 7486  1999 - 2000  Regular_Season  Dikembe Mutombo  ATL  82  2984.0  322
# 7487  1999 - 2000  Regular_Season      Jason Terry  ATL  81  1888.0  249
# 7488  1999 - 2000  Regular_Season      Bimbo Coles  ATL  80  1924.0  276
# 7489  1999 - 2000  Regular_Season  Lorenzen Wright  ATL  75  1205.0  180
#
#        FGA  3PM  3PA  ...  ORPG   DRPG   SPG   BPG   FPG    MPG   TPG  \
# ...

# %%
nba.columns
# Out:
# Index(['Season', 'Stage', 'Player', 'Team', 'GP', 'MIN', 'FGM', 'FGA', '3PM',
#        '3PA', 'FTM', 'FTA', 'TOV', 'PF', 'ORB', 'DRB', 'REB', 'AST', 'STL',
#        'BLK', 'PTS', 'birth_date', 'height_cm', 'weight_kg', 'nationality',
#        'PPG', 'APG', 'RPG', 'ORPG', 'DRPG', 'SPG', 'BPG', 'FPG', 'MPG', 'TPG',
#        'FT%', 'FG%', '3P%'],
#       dtype='object')

# %% [markdown]
# ### Reading and adding data to data frame

# %%
nba_records.head()
# Out:
#     Season   Lg             Team   W   L   W/L%  Finish   SRS  Pace  Rel_Pace  \
# 0  2017-18  NBA   Boston Celtics  29  10  0.744       1  4.38  95.4      -1.7
# 1  2016-17  NBA  Boston Celtics*  53  29  0.646       1  2.25  96.8       0.4
# 2  2015-16  NBA  Boston Celtics*  48  34  0.585       2  2.84  98.5       2.7
# 3  2014-15  NBA  Boston Celtics*  40  42  0.488       2 -0.40  95.8       1.9
# 4  2013-14  NBA   Boston Celtics  25  57  0.305       4 -4.97  93.3      -0.6
#
#     ORtg  Rel_ORtg   DRtg  Rel_DRtg                Playoffs  \
# 0  108.0       0.2  102.8      -5.0                     NaN
# 1  111.2       2.4  108.4      -0.4    Lost E. Conf. Finals
# 2  106.8       0.4  103.6      -2.8  Lost E. Conf. 1st Rnd.
# 3  104.7      -0.9  104.5      -1.1  Lost E. Conf. 1st Rnd.
# 4  102.9      -3.8  107.7       1.0                     NaN
#
#               Coaches            Top WS
# 0  B. Stevens (29-10)   K. Irving (5.7)
# 1  B. Stevens (53-29)  I. Thomas (12.5)
# ...

# %%
nba_records.drop(['Coaches', 'Lg', 'SRS', 'Pace', 'Rel_Pace', 'ORtg', 'Rel_ORtg', 'DRtg', 'Rel_DRtg', 'Playoffs', 'Top WS'], axis=1, inplace=True)

# %%
nba_records['Season'] = nba_records['Season'].replace({'2017-18' : '2017 - 2018', '2016-17': '2016 - 2017',
                                                        '2015-16': '2015 - 2016', '2014-15': '2014 - 2015',
                                                        '2013-14': '2013 - 2014', '2012-13': '2012 - 2013',
                                                        '2011-12': '2011 - 2012', '2010-11': '2010 - 2011',
                                                        '2009-10': '2009 - 2010', '2008-09': '2008 - 2009',
                                                        '2007-08': '2007 - 2008', '2006-07': '2006 - 2007',
                                                        '2005-06': '2005 - 2006', '2004-05': '2004 - 2005',
                                                        '2003-04': '2003 - 2004', '2002-03': '2002 - 2003',
                                                        '2001-02': '2001 - 2002', '2000-01': '2000 - 2001',
                                                        '1999-00': '1999 - 2000'})

# %%
season_list = ['2017 - 2018','2016 - 2017','2015 - 2016','2014 - 2015','2013 - 2014','2012 - 2013','2011 - 2012','2010 - 2011',
              '2009 - 2010','2008 - 2009','2007 - 2008','2006 - 2007','2005 - 2006','2004 - 2005','2003 - 2004','2002 - 2003',
              '2001 - 2002','2000 - 2001','1999 - 2000']
nba_records = nba_records[nba_records['Season'].isin(season_list)].reset_index()
nba_records.drop('index', axis=1)
# Out:
#           Season                 Team   W   L   W/L%  Finish
# 0    2017 - 2018       Boston Celtics  29  10  0.744       1
# 1    2016 - 2017      Boston Celtics*  53  29  0.646       1
# 2    2015 - 2016      Boston Celtics*  48  34  0.585       2
# 3    2014 - 2015      Boston Celtics*  40  42  0.488       2
# 4    2013 - 2014       Boston Celtics  25  57  0.305       4
# ..           ...                  ...  ..  ..    ...     ...
# 560  2003 - 2004   Memphis Grizzlies*  50  32  0.610       4
# 561  2002 - 2003    Memphis Grizzlies  28  54  0.341       6
# 562  2001 - 2002    Memphis Grizzlies  23  59  0.280       7
# 563  2000 - 2001  Vancouver Grizzlies  23  59  0.280       7
# 564  1999 - 2000  Vancouver Grizzlies  22  60  0.268       7
#
# [565 rows x 6 columns]

# %%
nba_records['Team'] = nba_records['Team'].replace({'Boston Celtics*': 'BOS' , 'Boston Celtics': 'BOS', 'Toronto Raptors*': 'TOR', 'Toronto Raptors': 'TOR',
                                                     'New York Knicks*': 'NYK', 'New York Knicks': 'NYK', 'Philadelphia 76ers*': 'PHI', 'Philadelphia 76ers': 'PHI',
                                                      'Brooklyn Nets': 'BRK', 'Brooklyn Nets*': 'BRK', 'New Jersey Nets': 'NJN', 'New Jersey Nets*': 'NJN',
                                                      'Minnesota Timberwolves': 'MIN', 'Minnesota Timberwolves*': 'MIN', 'Oklahoma City Thunder': 'OKC', 'Oklahoma City Thunder*': 'OKC',
                                                      'Seattle SuperSonics': 'SEA', 'Seattle SuperSonics*': 'SEA', 'Denver Nuggets': 'DEN', 'Denver Nuggets*': 'DEN',
                                                      'Portland Trail Blazers': 'POR', 'Portland Trail Blazers*': 'POR', 'Utah Jazz': 'UTA', 'Utah Jazz*': 'UTA',
                                                      'Cleveland Cavaliers': 'CLE', 'Cleveland Cavaliers*': 'CLE', 'Detroit Pistons': 'DET', 'Detroit Pistons*': 'DET',
                                                      'Milwaukee Bucks': 'MIL', 'Milwaukee Bucks*': 'MIL', 'Indiana Pacers': 'IND', 'Indiana Pacers*': 'IND',
                                                      'Chicago Bulls': 'CHI', 'Chicago Bulls*': 'CHI', 'Golden State Warriors': 'GSW', 'Golden State Warriors*': 'GSW',
                                                      'Los Angeles Clippers': 'LAC', 'Los Angeles Clippers*': 'LAC', 'Phoenix Suns': 'PHX',  'Phoenix Suns*': 'PHX',
                                                      'Sacramento Kings': 'SAC', 'Sacramento Kings*': 'SAC', 'Los Angeles Lakers': 'LAL', 'Los Angeles Lakers*': 'LAL',
                                                      'Washington Wizards': 'WAS', 'Washington Wizards*': 'WAS', 'Miami Heat': 'MIA', 'Miami Heat*': 'MIA',
                                                      'Charlotte Hornets': 'CHA', 'Charlotte Hornets*': 'CHA', 'Charlotte Bobcats*': 'CHA', 'Charlotte Bobcats': 'CHA',
                                                      'Orlando Magic': 'ORL', 'Orlando Magic*': 'ORL', 'Atlanta Hawks': 'ATL', 'Atlanta Hawks*': 'ATL',
                                                      'Houston Rockets': 'HOU', 'Houston Rockets*': 'HOU', 'San Antonio Spurs': 'SAS', 'San Antonio Spurs*': 'SAS',
                                                      'New Orleans Pelicans': 'NOP', 'New Orleans Pelicans*': 'NOP', 'New Orleans Hornets': 'NOP', 'New Orleans Hornets*': 'NOP',
                                                      'New Orleans/Oklahoma City Hornets': 'NOP', 'Dallas Mavericks': 'DAL', 'Dallas Mavericks*': 'DAL', 'Memphis Grizzlies': 'MEM',
                                                      'Memphis Grizzlies*': 'MEM', 'Vancouver Grizzlies': 'VAN'})
nba_records.drop('index', axis=1)
# Out:
#           Season Team   W   L   W/L%  Finish
# 0    2017 - 2018  BOS  29  10  0.744       1
# 1    2016 - 2017  BOS  53  29  0.646       1
# 2    2015 - 2016  BOS  48  34  0.585       2
# 3    2014 - 2015  BOS  40  42  0.488       2
# 4    2013 - 2014  BOS  25  57  0.305       4
# ..           ...  ...  ..  ..    ...     ...
# 560  2003 - 2004  MEM  50  32  0.610       4
# 561  2002 - 2003  MEM  28  54  0.341       6
# 562  2001 - 2002  MEM  23  59  0.280       7
# 563  2000 - 2001  VAN  23  59  0.280       7
# 564  1999 - 2000  VAN  22  60  0.268       7
#
# [565 rows x 6 columns]

# %%
nba_records.Finish
# Out:
# 0      1
# 1      1
# 2      2
# 3      2
# 4      4
#       ..
# 560    4
# 561    6
# 562    7
# 563    7
# 564    7
# Name: Finish, Length: 565, dtype: int64

# %%
nba = nba.merge(nba_records).drop(['index', 'Finish'], axis=1)

# %%
nba.columns
# Out:
# Index(['Season', 'Stage', 'Player', 'Team', 'GP', 'MIN', 'FGM', 'FGA', '3PM',
#        '3PA', 'FTM', 'FTA', 'TOV', 'PF', 'ORB', 'DRB', 'REB', 'AST', 'STL',
#        'BLK', 'PTS', 'birth_date', 'height_cm', 'weight_kg', 'nationality',
#        'PPG', 'APG', 'RPG', 'ORPG', 'DRPG', 'SPG', 'BPG', 'FPG', 'MPG', 'TPG',
#        'FT%', 'FG%', '3P%', 'W', 'L', 'W/L%'],
#       dtype='object')

# %%
nba
# Out:
#            Season           Stage            Player Team  GP     MIN  FGM  \
# 0     2017 - 2018  Regular_Season      Bradley Beal  WAS  82  2976.8  683
# 1     2017 - 2018  Regular_Season       Otto Porter  WAS  77  2431.6  445
# 2     2017 - 2018  Regular_Season  Kelly Oubre, Jr.  WAS  81  2230.5  318
# 3     2017 - 2018  Regular_Season   Markieff Morris  WAS  73  1967.9  330
# 4     2017 - 2018  Regular_Season     Marcin Gortat  WAS  82  2074.6  290
# ...           ...             ...               ...  ...  ..     ...  ...
# 6772  1999 - 2000  Regular_Season    Alan Henderson  ATL  82  2775.0  429
# 6773  1999 - 2000  Regular_Season   Dikembe Mutombo  ATL  82  2984.0  322
# 6774  1999 - 2000  Regular_Season       Jason Terry  ATL  81  1888.0  249
# 6775  1999 - 2000  Regular_Season       Bimbo Coles  ATL  80  1924.0  276
# 6776  1999 - 2000  Regular_Season   Lorenzen Wright  ATL  75  1205.0  180
#
#        FGA  3PM  3PA  ...   BPG   FPG    MPG   TPG       FT%       FG%  \
# ...

# %%
nba.dtypes
# Out:
# Season          object
# Stage           object
# Player          object
# Team            object
# GP               int64
# MIN            float64
# FGM              int64
# FGA              int64
# 3PM              int64
# 3PA              int64
# FTM              int64
# FTA              int64
# TOV              int64
# PF               int64
# ORB              int64
# DRB              int64
# REB              int64
# AST              int64
# STL              int64
# BLK              int64
# PTS              int64
# birth_date      object
# height_cm      float64
# weight_kg      float64
# nationality     object
# PPG            float64
# APG            float64
# RPG            float64
# ORPG           float64
# DRPG           float64
# SPG            float64
# BPG            float64
# FPG            float64
# MPG            float64
# TPG            float64
# FT%            float64
# FG%            float64
# 3P%            float64
# W                int64
# L                int64
# ...

# %%
nba.isna().sum()
# Out:
# Season            0
# Stage             0
# Player            0
# Team              0
# GP                0
# MIN               0
# FGM               0
# FGA               0
# 3PM               0
# 3PA               0
# FTM               0
# FTA               0
# TOV               0
# PF                0
# ORB               0
# DRB               0
# REB               0
# AST               0
# STL               0
# BLK               0
# PTS               0
# birth_date        0
# height_cm         0
# weight_kg         0
# nationality       0
# PPG               0
# APG               0
# RPG               0
# ORPG              0
# DRPG              0
# SPG               0
# BPG               0
# FPG               0
# MPG               0
# TPG               0
# FT%            1233
# FG%             127
# 3P%            2558
# W                 0
# L                 0
# W/L%              0
# dtype: int64

# %%
nba.describe()
# Out:
#                 GP          MIN          FGM          FGA          3PM  \
# count  6777.000000  6777.000000  6777.000000  6777.000000  6777.000000
# mean     48.957798  1311.102184   206.097683   451.552900    37.853180
# std      32.093728   984.908559   185.800694   400.855463    50.503271
# min       3.000000    60.000000     0.000000     2.000000     0.000000
# 25%      11.000000   260.000000    36.000000    83.000000     1.000000
# 50%      68.000000  1335.000000   168.000000   369.000000    12.000000
# 75%      78.000000  2163.500000   322.000000   712.000000    64.000000
# max      85.000000  3485.000000   978.000000  2173.000000   402.000000
#
#                3PA          FTM          FTA          TOV           PF  ...  \
# count  6777.000000  6777.000000  6777.000000  6777.000000  6777.000000  ...
# mean    104.851852   103.760218   136.049579    75.020068   110.591855  ...
# std     132.955019   114.074234   145.094172    68.239060    81.287715  ...
# ...

# %%
writer = pd.ExcelWriter('nba_data_file.xlsx', engine='xlsxwriter')
nba.to_excel(writer, index=False)
writer.save()
